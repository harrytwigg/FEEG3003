# %% [markdown]
# ### Project initialization
# Setup the environment with correct path and imports

# %%
# Environment variables:

SAMPLE_RATE = 16000
FRAME_RATE = 250

# %%
from pathlib import Path
import os

PROJECT_PATH = Path('.').resolve().parent.parent
print("PROJECT_PATH:", PROJECT_PATH)

import ddsp
from typing import List, Tuple
from ddsp.training.data_preparation.prepare_tfrecord_lib import prepare_tfrecord

if not PROJECT_PATH.exists():
    raise Exception(f'Project path {PROJECT_PATH} does not exist')

# Check if separated data exists
SEPERATED_PATH = PROJECT_PATH.joinpath('separated')

if not SEPERATED_PATH.exists():
    raise Exception(f"Separated data path not found at '{SEPERATED_PATH}'") 

print("SEPERATED_PATH:", SEPERATED_PATH)
# Out:
# PROJECT_PATH: /home/harry/Documents/FEEG3003/vocal_ddsp
# SEPERATED_PATH: /home/harry/Documents/FEEG3003/vocal_ddsp/separated

# %% [markdown]
# ### Data preparation
# A TFRecordDataSet is created from a specified path in the separated folder, this is then exported to the dataset folder.

# %%
TRAINING_DATASET_PATH = f"{str(PROJECT_PATH)}/training_data"

def prepare_dataset(folder: str):
    """Prepares a TFRecordDataSet from a selection of files in the separated folder"""

    if isinstance(folder, str):
        # If starting with a '/' remove it
        if folder.startswith('/'):
            folder = folder[1:]
        # If ending with '/' remove it
        if folder[-1] == '/':
            folder = folder[:-1]
        
        actual_path = f"{str(SEPERATED_PATH)}/{folder}"
    else:
        raise Exception(f"Folder must be a string, not {type(folder)}")
    
    output_name = folder.replace('/', '_').replace(' ', '_')

    print("actual_path", actual_path)
    if not Path(actual_path).exists():
      raise Exception(f"The actual_path {actual_path} does not exist")

    # If ends with _, remove it
    if output_name.endswith('_'):
        output_name = output_name[:-1]
    
    output_folder = f"{TRAINING_DATASET_PATH}/{output_name}/"
    print(f"Output folder: {output_folder}")

    if not Path(output_folder).exists():
        os.makedirs(Path(output_folder))
        assert Path(output_folder).exists()
      
    # Get all wav files in path
    input_paths = list(Path(actual_path).glob('**/*.wav'))
    print(f"Found {len(input_paths)} wav files in {actual_path}")

    # Convert inpited paths to strings
    input_paths = [str(path) for path in input_paths]

    print("input_paths:", input_paths)

    output_path = f"{output_folder}train.tfrecord"

    prepare_tfrecord(input_paths, output_path, num_shards=10, frame_rate=250)

# %%
prepare_dataset("ColdplaySelected")
# Out:
# actual_path /home/harry/Documents/FEEG3003/vocal_ddsp/separated/ColdplaySelected
# Output folder: /home/harry/Documents/FEEG3003/vocal_ddsp/training_data/ColdplaySelected/
# Found 20 wav files in /home/harry/Documents/FEEG3003/vocal_ddsp/separated/ColdplaySelected
# input_paths: ['/home/harry/Documents/FEEG3003/vocal_ddsp/separated/ColdplaySelected/Coldplay - A Rush of Blood to the Head/03 - God Put a Smile upon Your Face/03 - God Put a Smile upon Your Face/vocals.wav', '/home/harry/Documents/FEEG3003/vocal_ddsp/separated/ColdplaySelected/Coldplay - A Rush of Blood to the Head/05 - Clocks/05 - Clocks/vocals.wav', '/home/harry/Documents/FEEG3003/vocal_ddsp/separated/ColdplaySelected/Coldplay - A Rush of Blood to the Head/10 - A Rush of Blood to the Head/10 - A Rush of Blood to the Head/vocals.wav', '/home/harry/Documents/FEEG3003/vocal_ddsp/separated/ColdplaySelected/Coldplay - A Rush of Blood to the Head/02 - In My Place/02 - In My Place/vocals.wav', '/home/harry/Documents/FEEG3003/vocal_ddsp/separated/ColdplaySelected/Coldplay - A Rush of Blood to the Head/06 - Daylight/06 - Daylight/vocals.wav', '/home/harry/Documents/FEEG3003/vocal_ddsp/separated/ColdplaySelected/Coldplay - A Rush of Blood to the Head/08 - Warning Sign/08 - Warning Sign/vocals.wav', '/home/harry/Documents/FEEG3003/vocal_ddsp/separated/ColdplaySelected/Coldplay - A Rush of Blood to the Head/07 - Green Eyes/07 - Green Eyes/vocals.wav', '/home/harry/Documents/FEEG3003/vocal_ddsp/separated/ColdplaySelected/Coldplay - A Rush of Blood to the Head/01 - Politik/01 - Politik/vocals.wav', '/home/harry/Documents/FEEG3003/vocal_ddsp/separated/ColdplaySelected/Coldplay - A Rush of Blood to the Head/11 - Amsterdam/11 - Amsterdam/vocals.wav', '/home/harry/Documents/FEEG3003/vocal_ddsp/separated/ColdplaySelected/Coldplay - A Rush of Blood to the Head/09 - A Whisper/09 - A Whisper/vocals.wav', '/home/harry/Documents/FEEG3003/vocal_ddsp/separated/ColdplaySelected/Coldplay - A Rush of Blood to the Head/04 - The Scientist/04 - The Scientist/vocals.wav', '/home/harry/Documents/FEEG3003/vocal_ddsp/separated/ColdplaySelected/Coldplay - Ghost Stories/05 - Midnight/05 - Midnight/vocals.wav', '/home/harry/Documents/FEEG3003/vocal_ddsp/separated/ColdplaySelected/Coldplay - Ghost Stories/04 - True Love/04 - True Love/vocals.wav', '/home/harry/Documents/FEEG3003/vocal_ddsp/separated/ColdplaySelected/Coldplay - Ghost Stories/07 - Oceans/07 - Oceans/vocals.wav', '/home/harry/Documents/FEEG3003/vocal_ddsp/separated/ColdplaySelected/Coldplay - Ghost Stories/01 - Always in My Head/01 - Always in My Head/vocals.wav', "/home/harry/Documents/FEEG3003/vocal_ddsp/separated/ColdplaySelected/Coldplay - Ghost Stories/06 - Another's Arms/06 - Another's Arms/vocals.wav", '/home/harry/Documents/FEEG3003/vocal_ddsp/separated/ColdplaySelected/Coldplay - Ghost Stories/02 - Magic/02 - Magic/vocals.wav', '/home/harry/Documents/FEEG3003/vocal_ddsp/separated/ColdplaySelected/Coldplay - Ghost Stories/09 - O/09 - O/vocals.wav', '/home/harry/Documents/FEEG3003/vocal_ddsp/separated/ColdplaySelected/Coldplay - Ghost Stories/08 - A Sky Full of Stars/08 - A Sky Full of Stars/vocals.wav', '/home/harry/Documents/FEEG3003/vocal_ddsp/separated/ColdplaySelected/Coldplay - Ghost Stories/03 - Ink/03 - Ink/vocals.wav']
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.7 interpreter.
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner.process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.PerWindowInvoker.invoke_process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.PerWindowInvoker._invoke_process_per_window()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/transforms/core.py in <lambda>(x, *args, **kwargs)
#    1635   if fn_takes_side_inputs(fn):
# -> 1636     wrapper = lambda x, *args, **kwargs: [fn(x, *args, **kwargs)]
#    1637   else:
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/ddsp/training/data_preparation/prepare_tfrecord_lib.py in _add_f0_estimate(ex, frame_rate, center, viterbi)
#      80   f0_hz, f0_confidence = spectral_ops.compute_f0(
# ---> 81       audio, frame_rate, viterbi=viterbi, padding=padding)
#      82   ex = dict(ex)
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/ddsp/spectral_ops.py in compute_f0(audio, frame_rate, viterbi, padding)
#     359       center=False,
# --> 360       verbose=0)
#     361
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/crepe/core.py in predict(audio, sr, model_capacity, viterbi, center, step_size, verbose)
#     256                                 center=center, step_size=step_size,
# --> 257                                 verbose=verbose)
#     258     confidence = activation.max(axis=1)
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/crepe/core.py in get_activation(audio, sr, model_capacity, center, step_size, verbose)
#     211     # run prediction and convert the frequency bin weights to Hz
# --> 212     return model.predict(frames, verbose=verbose)
#     213
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# UnimplementedError: Graph execution error:
#
# Detected at node 'model/conv1/Conv2D' defined at (most recent call last):
#     File "/home/harry/Python37/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#       "__main__", mod_spec)
#     File "/home/harry/Python37/lib/python3.7/runpy.py", line 85, in _run_code
#       exec(code, run_globals)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#       app.launch_new_instance()
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/traitlets/config/application.py", line 846, in launch_instance
#       app.start()
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 619, in start
#       self.io_loop.start()
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "/home/harry/Python37/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#       self._run_once()
#     File "/home/harry/Python37/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#       handle._run()
#     File "/home/harry/Python37/lib/python3.7/asyncio/events.py", line 88, in _run
#       self._context.run(self._callback, *self._args)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/tornado/ioloop.py", line 688, in <lambda>
#       lambda f: self._run_callback(functools.partial(callback, future))
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/tornado/ioloop.py", line 741, in _run_callback
#       ret = callback()
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/tornado/gen.py", line 814, in inner
#       self.ctx_run(self.run)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/tornado/gen.py", line 775, in run
#       yielded = self.gen.send(value)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 361, in process_one
#       yield gen.maybe_future(dispatch(*args))
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#       yielded = ctx_run(next, result)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 261, in dispatch_shell
#       yield gen.maybe_future(handler(stream, idents, msg))
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#       yielded = ctx_run(next, result)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 541, in execute_request
#       user_expressions, allow_stdin,
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#       yielded = ctx_run(next, result)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 302, in do_execute
#       res = shell.run_cell(code, store_history=store_history, silent=silent)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 539, in run_cell
#       return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2958, in run_cell
#       raw_cell, store_history, silent, shell_futures)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3003, in _run_cell
#       return runner(coro)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#       coro.send(None)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3229, in run_cell_async
#       interactivity=interactivity, compiler=compiler, result=result)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3444, in run_ast_nodes
#       if (await self.run_code(code, result,  async_=asy)):
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3524, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "<ipython-input-4-bc927bced3c9>", line 1, in <module>
#       prepare_dataset("ColdplaySelected")
#     File "<ipython-input-3-890e33c08e93>", line 46, in prepare_dataset
#       prepare_tfrecord(input_paths, output_path, num_shards=10, frame_rate=250)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/ddsp/training/data_preparation/prepare_tfrecord_lib.py", line 263, in prepare_tfrecord
#       postprocess_pipeline(examples, output_tfrecord_path)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/pipeline.py", line 596, in __exit__
#       self.result = self.run()
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/pipeline.py", line 573, in run
#       return self.runner.run_pipeline(self, self._options)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/direct/direct_runner.py", line 131, in run_pipeline
#       return runner.run_pipeline(pipeline, options)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/portability/fn_api_runner/fn_runner.py", line 200, in run_pipeline
#       pipeline.to_runner_api(default_environment=self._default_environment))
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/portability/fn_api_runner/fn_runner.py", line 210, in run_via_runner_api
#       return self.run_stages(stage_context, stages)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/portability/fn_api_runner/fn_runner.py", line 393, in run_stages
#       runner_execution_context, bundle_context_manager)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/portability/fn_api_runner/fn_runner.py", line 664, in _run_stage
#       bundle_manager))
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/portability/fn_api_runner/fn_runner.py", line 781, in _run_bundle
#       data_input, data_output, input_timers, expected_timer_output)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/portability/fn_api_runner/fn_runner.py", line 1091, in process_bundle
#       result_future = self._worker_handler.control_conn.push(process_bundle_req)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/portability/fn_api_runner/worker_handlers.py", line 378, in push
#       response = self.worker.do_instruction(request)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/sdk_worker.py", line 581, in do_instruction
#       getattr(request, request_type), request.instruction_id)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/sdk_worker.py", line 618, in process_bundle
#       bundle_processor.process_bundle(instruction_id))
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/bundle_processor.py", line 996, in process_bundle
#       element.data)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/bundle_processor.py", line 221, in process_encoded
#       self.output(decoded_value)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/transforms/core.py", line 1636, in <lambda>
#       wrapper = lambda x, *args, **kwargs: [fn(x, *args, **kwargs)]
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/ddsp/training/data_preparation/prepare_tfrecord_lib.py", line 81, in _add_f0_estimate
#       audio, frame_rate, viterbi=viterbi, padding=padding)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/ddsp/spectral_ops.py", line 360, in compute_f0
#       verbose=0)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/crepe/core.py", line 257, in predict
#       verbose=verbose)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/crepe/core.py", line 212, in get_activation
#       return model.predict(frames, verbose=verbose)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/engine/training.py", line 1982, in predict
#       tmp_batch_outputs = self.predict_function(iterator)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/engine/training.py", line 1801, in predict_function
#       return step_function(self, iterator)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/engine/training.py", line 1790, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/engine/training.py", line 1783, in run_step
#       outputs = model.predict_step(data)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/engine/training.py", line 1751, in predict_step
#       return self(x, training=False)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/engine/base_layer.py", line 1096, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 92, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/engine/functional.py", line 452, in call
#       inputs, training=training, mask=mask)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/engine/functional.py", line 589, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/engine/base_layer.py", line 1096, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 92, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/layers/convolutional.py", line 248, in call
#       outputs = self.convolution_op(inputs, self.kernel)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/layers/convolutional.py", line 240, in convolution_op
#       name=self.__class__.__name__)
# Node: 'model/conv1/Conv2D'
# DNN library is not found.
# 	 [[{{node model/conv1/Conv2D}}]] [Op:__inference_predict_function_817]
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-bc927bced3c9> in <module>
# ----> 1 prepare_dataset("ColdplaySelected")
#
# <ipython-input-3-890e33c08e93> in prepare_dataset(folder)
#      44     output_path = f"{output_folder}train.tfrecord"
#      45
# ---> 46     prepare_tfrecord(input_paths, output_path, num_shards=10, frame_rate=250)
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/ddsp/training/data_preparation/prepare_tfrecord_lib.py in prepare_tfrecord(input_audio_paths, output_tfrecord_path, num_shards, sample_rate, frame_rate, example_secs, hop_secs, eval_split_fraction, chunk_secs, center, viterbi, pipeline_options)
#     261                            'train')
#     262     else:
# --> 263       postprocess_pipeline(examples, output_tfrecord_path)
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/pipeline.py in __exit__(self, exc_type, exc_val, exc_tb)
#     594     try:
#     595       if not exc_type:
# --> 596         self.result = self.run()
#     597         self.result.wait_until_finish()
#     598     finally:
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/pipeline.py in run(self, test_runner_api)
#     571         finally:
#     572           shutil.rmtree(tmpdir)
# --> 573       return self.runner.run_pipeline(self, self._options)
#     574     finally:
#     575       if not is_in_ipython():
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/direct/direct_runner.py in run_pipeline(self, pipeline, options)
#     129       runner = BundleBasedDirectRunner()
#     130
# --> 131     return runner.run_pipeline(pipeline, options)
#     132
#     133
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/portability/fn_api_runner/fn_runner.py in run_pipeline(self, pipeline, options)
#     198
#     199     self._latest_run_result = self.run_via_runner_api(
# --> 200         pipeline.to_runner_api(default_environment=self._default_environment))
#     201     return self._latest_run_result
#     202
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/portability/fn_api_runner/fn_runner.py in run_via_runner_api(self, pipeline_proto)
#     208     # TODO(pabloem, BEAM-7514): Create a watermark manager (that has access to
#     209     #   the teststream (if any), and all the stages).
# --> 210     return self.run_stages(stage_context, stages)
#     211
#     212   @contextlib.contextmanager
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/portability/fn_api_runner/fn_runner.py in run_stages(self, stage_context, stages)
#     391
#     392           stage_results = self._run_stage(
# --> 393               runner_execution_context, bundle_context_manager)
#     394
#     395           assert (
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/portability/fn_api_runner/fn_runner.py in _run_stage(self, runner_execution_context, bundle_context_manager)
#     662               input_timers,
#     663               expected_timer_output,
# --> 664               bundle_manager))
#     665
#     666       for pc_name, watermark in watermark_updates.items():
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/portability/fn_api_runner/fn_runner.py in _run_bundle(self, runner_execution_context, bundle_context_manager, data_input, data_output, input_timers, expected_timer_output, bundle_manager)
#     779
#     780     result, splits = bundle_manager.process_bundle(
# --> 781         data_input, data_output, input_timers, expected_timer_output)
#     782     # Now we collect all the deferred inputs remaining from bundle execution.
#     783     # Deferred inputs can be:
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/portability/fn_api_runner/fn_runner.py in process_bundle(self, inputs, expected_outputs, fired_timers, expected_output_timers, dry_run)
#    1089             process_bundle_descriptor.id,
#    1090             cache_tokens=[next(self._cache_token_generator)]))
# -> 1091     result_future = self._worker_handler.control_conn.push(process_bundle_req)
#    1092
#    1093     split_results = []  # type: List[beam_fn_api_pb2.ProcessBundleSplitResponse]
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/portability/fn_api_runner/worker_handlers.py in push(self, request)
#     376       self._uid_counter += 1
#     377       request.instruction_id = 'control_%s' % self._uid_counter
# --> 378     response = self.worker.do_instruction(request)
#     379     return ControlFuture(request.instruction_id, response)
#     380
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/sdk_worker.py in do_instruction(self, request)
#     579       # E.g. if register is set, this will call self.register(request.register))
#     580       return getattr(self, request_type)(
# --> 581           getattr(request, request_type), request.instruction_id)
#     582     else:
#     583       raise NotImplementedError
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/sdk_worker.py in process_bundle(self, request, instruction_id)
#     616         with self.maybe_profile(instruction_id):
#     617           delayed_applications, requests_finalization = (
# --> 618               bundle_processor.process_bundle(instruction_id))
#     619           monitoring_infos = bundle_processor.monitoring_infos()
#     620           monitoring_infos.extend(self.state_cache_metrics_fn())
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/bundle_processor.py in process_bundle(self, instruction_id)
#     994           elif isinstance(element, beam_fn_api_pb2.Elements.Data):
#     995             input_op_by_transform_id[element.transform_id].process_encoded(
# --> 996                 element.data)
#     997
#     998       # Finish all operations.
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/bundle_processor.py in process_encoded(self, encoded_windowed_values)
#     219       decoded_value = self.windowed_coder_impl.decode_from_stream(
#     220           input_stream, True)
# --> 221       self.output(decoded_value)
#     222
#     223   def monitoring_infos(self, transform_id, tag_to_pcollection_id):
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.Operation.output()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.Operation.output()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.SingletonConsumerSet.receive()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner.process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner._reraise_augmented()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner.process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.SimpleInvoker.invoke_process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common._OutputProcessor.process_outputs()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.SingletonConsumerSet.receive()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner.process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner._reraise_augmented()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner.process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.SimpleInvoker.invoke_process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common._OutputProcessor.process_outputs()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.SingletonConsumerSet.receive()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner.process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner._reraise_augmented()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner.process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.SimpleInvoker.invoke_process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common._OutputProcessor.process_outputs()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.SingletonConsumerSet.receive()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner.process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner._reraise_augmented()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner.process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.PerWindowInvoker.invoke_process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.PerWindowInvoker._invoke_process_per_window()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common._OutputProcessor.process_outputs()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.SingletonConsumerSet.receive()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner.process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner._reraise_augmented()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner.process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.PerWindowInvoker.invoke_process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.PerWindowInvoker._invoke_process_per_window()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common._OutputProcessor.process_outputs()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.SingletonConsumerSet.receive()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.DoOperation.process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner.process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner._reraise_augmented()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner.process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.PerWindowInvoker.invoke_process()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.PerWindowInvoker._invoke_process_per_window()
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/transforms/core.py in <lambda>(x, *args, **kwargs)
#    1634   from apache_beam.transforms.util import fn_takes_side_inputs
#    1635   if fn_takes_side_inputs(fn):
# -> 1636     wrapper = lambda x, *args, **kwargs: [fn(x, *args, **kwargs)]
#    1637   else:
#    1638     wrapper = lambda x: [fn(x)]
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/ddsp/training/data_preparation/prepare_tfrecord_lib.py in _add_f0_estimate(ex, frame_rate, center, viterbi)
#      79   padding = 'center' if center else 'same'
#      80   f0_hz, f0_confidence = spectral_ops.compute_f0(
# ---> 81       audio, frame_rate, viterbi=viterbi, padding=padding)
#      82   ex = dict(ex)
#      83   ex.update({
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/ddsp/spectral_ops.py in compute_f0(audio, frame_rate, viterbi, padding)
#     358       step_size=crepe_step_size,
#     359       center=False,
# --> 360       verbose=0)
#     361
#     362   # Postprocessing.
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/crepe/core.py in predict(audio, sr, model_capacity, viterbi, center, step_size, verbose)
#     255     activation = get_activation(audio, sr, model_capacity=model_capacity,
#     256                                 center=center, step_size=step_size,
# --> 257                                 verbose=verbose)
#     258     confidence = activation.max(axis=1)
#     259
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/crepe/core.py in get_activation(audio, sr, model_capacity, center, step_size, verbose)
#     210
#     211     # run prediction and convert the frequency bin weights to Hz
# --> 212     return model.predict(frames, verbose=verbose)
#     213
#     214
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# RuntimeError: tensorflow.python.framework.errors_impl.UnimplementedError: Graph execution error:
#
# Detected at node 'model/conv1/Conv2D' defined at (most recent call last):
#     File "/home/harry/Python37/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#       "__main__", mod_spec)
#     File "/home/harry/Python37/lib/python3.7/runpy.py", line 85, in _run_code
#       exec(code, run_globals)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#       app.launch_new_instance()
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/traitlets/config/application.py", line 846, in launch_instance
#       app.start()
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 619, in start
#       self.io_loop.start()
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "/home/harry/Python37/lib/python3.7/asyncio/base_events.py", line 541, in run_forever
#       self._run_once()
#     File "/home/harry/Python37/lib/python3.7/asyncio/base_events.py", line 1786, in _run_once
#       handle._run()
#     File "/home/harry/Python37/lib/python3.7/asyncio/events.py", line 88, in _run
#       self._context.run(self._callback, *self._args)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/tornado/ioloop.py", line 688, in <lambda>
#       lambda f: self._run_callback(functools.partial(callback, future))
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/tornado/ioloop.py", line 741, in _run_callback
#       ret = callback()
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/tornado/gen.py", line 814, in inner
#       self.ctx_run(self.run)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/tornado/gen.py", line 775, in run
#       yielded = self.gen.send(value)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 361, in process_one
#       yield gen.maybe_future(dispatch(*args))
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#       yielded = ctx_run(next, result)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 261, in dispatch_shell
#       yield gen.maybe_future(handler(stream, idents, msg))
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#       yielded = ctx_run(next, result)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 541, in execute_request
#       user_expressions, allow_stdin,
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/tornado/gen.py", line 234, in wrapper
#       yielded = ctx_run(next, result)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 302, in do_execute
#       res = shell.run_cell(code, store_history=store_history, silent=silent)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 539, in run_cell
#       return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2958, in run_cell
#       raw_cell, store_history, silent, shell_futures)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3003, in _run_cell
#       return runner(coro)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#       coro.send(None)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3229, in run_cell_async
#       interactivity=interactivity, compiler=compiler, result=result)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3444, in run_ast_nodes
#       if (await self.run_code(code, result,  async_=asy)):
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3524, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "<ipython-input-4-bc927bced3c9>", line 1, in <module>
#       prepare_dataset("ColdplaySelected")
#     File "<ipython-input-3-890e33c08e93>", line 46, in prepare_dataset
#       prepare_tfrecord(input_paths, output_path, num_shards=10, frame_rate=250)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/ddsp/training/data_preparation/prepare_tfrecord_lib.py", line 263, in prepare_tfrecord
#       postprocess_pipeline(examples, output_tfrecord_path)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/pipeline.py", line 596, in __exit__
#       self.result = self.run()
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/pipeline.py", line 573, in run
#       return self.runner.run_pipeline(self, self._options)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/direct/direct_runner.py", line 131, in run_pipeline
#       return runner.run_pipeline(pipeline, options)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/portability/fn_api_runner/fn_runner.py", line 200, in run_pipeline
#       pipeline.to_runner_api(default_environment=self._default_environment))
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/portability/fn_api_runner/fn_runner.py", line 210, in run_via_runner_api
#       return self.run_stages(stage_context, stages)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/portability/fn_api_runner/fn_runner.py", line 393, in run_stages
#       runner_execution_context, bundle_context_manager)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/portability/fn_api_runner/fn_runner.py", line 664, in _run_stage
#       bundle_manager))
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/portability/fn_api_runner/fn_runner.py", line 781, in _run_bundle
#       data_input, data_output, input_timers, expected_timer_output)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/portability/fn_api_runner/fn_runner.py", line 1091, in process_bundle
#       result_future = self._worker_handler.control_conn.push(process_bundle_req)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/portability/fn_api_runner/worker_handlers.py", line 378, in push
#       response = self.worker.do_instruction(request)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/sdk_worker.py", line 581, in do_instruction
#       getattr(request, request_type), request.instruction_id)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/sdk_worker.py", line 618, in process_bundle
#       bundle_processor.process_bundle(instruction_id))
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/bundle_processor.py", line 996, in process_bundle
#       element.data)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/runners/worker/bundle_processor.py", line 221, in process_encoded
#       self.output(decoded_value)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/apache_beam/transforms/core.py", line 1636, in <lambda>
#       wrapper = lambda x, *args, **kwargs: [fn(x, *args, **kwargs)]
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/ddsp/training/data_preparation/prepare_tfrecord_lib.py", line 81, in _add_f0_estimate
#       audio, frame_rate, viterbi=viterbi, padding=padding)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/ddsp/spectral_ops.py", line 360, in compute_f0
#       verbose=0)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/crepe/core.py", line 257, in predict
#       verbose=verbose)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/crepe/core.py", line 212, in get_activation
#       return model.predict(frames, verbose=verbose)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/engine/training.py", line 1982, in predict
#       tmp_batch_outputs = self.predict_function(iterator)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/engine/training.py", line 1801, in predict_function
#       return step_function(self, iterator)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/engine/training.py", line 1790, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/engine/training.py", line 1783, in run_step
#       outputs = model.predict_step(data)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/engine/training.py", line 1751, in predict_step
#       return self(x, training=False)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/engine/base_layer.py", line 1096, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 92, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/engine/functional.py", line 452, in call
#       inputs, training=training, mask=mask)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/engine/functional.py", line 589, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/engine/base_layer.py", line 1096, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/utils/traceback_utils.py", line 92, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/layers/convolutional.py", line 248, in call
#       outputs = self.convolution_op(inputs, self.kernel)
#     File "/home/harry/Documents/FEEG3003/vocal_ddsp/venv/lib/python3.7/site-packages/keras/layers/convolutional.py", line 240, in convolution_op
#       name=self.__class__.__name__)
# Node: 'model/conv1/Conv2D'
# DNN library is not found.
# 	 [[{{node model/conv1/Conv2D}}]] [Op:__inference_predict_function_817] [while running 'Map(_add_f0_estimate)']

# %% [markdown]
# ### Check the dataset
# Import utils and plot and listen to a part of the trained dataset

# %%
from ddsp.colab import colab_utils
from ddsp.colab.colab_utils import play, specplot
from matplotlib import pyplot as plt
import numpy as np
import tensorflow as tf

def get_frame(relative_path, frame_rate=250):
  """Gets a frame from a training dataset"""
  dataset_pattern = f"{TRAINING_DATASET_PATH}/{str(relative_path)}/*"

  if not Path(dataset_pattern[:-2]).exists():
    raise Exception(f"The dataset path {dataset_pattern[:-2]} doesn't exist")
  
  data_provider = ddsp.training.data.TFRecordProvider(dataset_pattern, frame_rate=frame_rate)

  dataset = data_provider.get_dataset(shuffle=False)

  try:
    for i, frame in enumerate(iter(dataset)):
      # Get a 4 second frame someway thorugh the song
      if i == 40:
        return frame
  except StopIteration:
    raise Exception(
        'TFRecord contains no examples. Please try re-running the pipeline with '
        'different audio file(s).')
  except OutOfRangeError:
    raise Exception(
        'TFRecord contains no examples. Please try re-running the pipeline with '
        'different audio file(s).')

# %%
frame = get_frame("lakes")

colab_utils.specplot(frame['audio'])
colab_utils.play(frame['audio'])

f, ax = plt.subplots(3, 1, figsize=(12, 8))
x = np.linspace(0, 4.0, frame['loudness_db'].shape[0])
ax[0].set_ylabel('loudness_db')
ax[0].plot(x, frame['loudness_db'])
ax[1].set_ylabel('f0_Hz')
ax[1].plot(x, frame['f0_hz'])
ax[2].set_ylabel('f0_confidence')
ax[2].set_xlabel('seconds')
_ = ax[2].plot(x, frame['f0_confidence'])
